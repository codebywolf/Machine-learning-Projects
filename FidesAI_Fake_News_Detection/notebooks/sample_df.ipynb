# %%
import numpy as np
import pandas as pd

# %%
def sample (data_path: str = '../data/processed/sample_suggestions.csv'):
    df = pd.read_csv(data_path)
    example = df.sample(1)
    news = example.text.values[0]
    label = example.label.values[0]
    return news, label
